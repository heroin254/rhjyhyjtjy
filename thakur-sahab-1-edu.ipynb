# %%
import os
from kaggle_secrets import UserSecretsClient

print("🔐 Loading Secrets & API Keys...")
user_secrets = UserSecretsClient()

os.environ["XKIRO_API_KEY"] = user_secrets.get_secret("XKIRO_API_KEY")
os.environ["GNANI_API_KEY"] = user_secrets.get_secret("GNANI_API_KEY")
os.environ["PIXABAY_API_KEY"] = user_secrets.get_secret("PIXABAY_API_KEY")
os.environ["FREESOUND_API_KEY"] = user_secrets.get_secret("FREESOUND_API_KEY")
os.environ["YOUTUBE_TOKEN_BASE64"] = user_secrets.get_secret("YOUTUBE_TOKEN_BASE64")
os.environ["BOT_TOKEN"] = user_secrets.get_secret("BOT_TOKEN")
os.environ["CHAT_ID"] = user_secrets.get_secret("CHAT_ID")

print("📂 Fetching files from Linked GitHub (Bulletproof method)...")
# 🟢 THE FIX: Kaggle ke kisi bhi kone se aapki files nikal kar Working folder mein layega
# !find /kaggle/input -type f -name "*.py" -exec cp {} /kaggle/working/ \;
# !find /kaggle/input -type f -name "*.json" -exec cp {} /kaggle/working/ \;
# !find /kaggle/input -type f -name "*.png" -exec cp {} /kaggle/working/ \;
# !find /kaggle/input -type f -name "*.ttf" -exec cp {} /kaggle/working/ \;

print("⚙️ Installing Dependencies (Ignore red pip errors!)...")
# !apt-get update -y > /dev/null 2>&1
# !apt-get install -y ffmpeg imagemagick > /dev/null 2>&1
# !sed -i 's/rights="none"/rights="read|write"/' /etc/ImageMagick-6/policy.xml
# !pip install -q moviepy==1.0.3 openai requests playwright numpy Pillow==9.5.0 imageio-ffmpeg google-api-python-client google-auth-httplib2 google-auth-oauthlib
# !playwright install chromium > /dev/null 2>&1
# !playwright install-deps chromium > /dev/null 2>&1

if os.path.exists("1_generate_content.py"):
    print("🚀 Launching the SaaS Bots...")
    # !python 1_generate_content.py
    # !python 2_generate_images.py 1 & python 2_generate_images.py 2 & python 2_generate_images.py 3 & python 2_generate_images.py thumb & wait
    # !python 3_render_video.py
    # !python 4_upload_youtube.py
    print("🎉 ALL TASKS COMPLETED SUCCESSFULLY!")
else:
    print("❌ ERROR: Files abhi bhi nahi aayi! Kaggle ke upar wale menu mein 'File > Link to GitHub' dobara check karein.")
# Out:
# 🔐 Loading Secrets & API Keys...
# 📂 Fetching files from Linked GitHub (Bulletproof method)...
# ⚙️ Installing Dependencies (Ignore red pip errors!)...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 MB 27.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 MB 27.2 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mne 1.12.1 requires decorator>=5.1, but you have decorator 4.4.2 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# scikit-image 0.25.2 requires pillow>=10.1, but you have pillow 9.5.0 which is incompatible.
# ❌ ERROR: Files abhi bhi nahi aayi! Kaggle ke upar wale menu mein 'File > Link to GitHub' dobara check karein.
